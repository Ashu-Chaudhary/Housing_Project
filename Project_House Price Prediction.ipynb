# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Data file.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df['LotFrontage'].fillna(df['LotFrontage'].mean(),inplace=True)

# %%
df['MasVnrType'].fillna(df['MasVnrType'].mode(),inplace=True)

# %%
df['MasVnrArea'].fillna(df['MasVnrArea'].mode(),inplace=True)

# %%
df['BsmtQual'].fillna(df['BsmtQual'].mode(),inplace=True)

# %%
df['BsmtCond'].fillna(df['BsmtCond'].mode(),inplace=True)

# %%
df['BsmtExposure'].fillna(df['BsmtExposure'].mode(),inplace=True)

# %%
df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode(),inplace=True)

# %%
df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode(),inplace=True)

# %%
df['Electrical'].fillna(df['Electrical'].mode(),inplace=True)

# %%
df['GarageType'].fillna(df['GarageType'].mode(),inplace=True)

# %%
df['GarageYrBlt'].fillna(df['GarageYrBlt'].mode(),inplace=True)

# %%
df['GarageFinish'].fillna(df['GarageFinish'].mode(),inplace=True)

# %%
df['GarageQual'].fillna(df['GarageQual'].mode(),inplace=True)

# %%
df['GarageCond'].fillna(df['GarageCond'].mode(),inplace=True)

# %%
df = df.drop(['Fence', 'MiscFeature', 'PoolQC','FireplaceQu','Alley'], axis=1)

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.factorplot(x='MSZoning', y='SalePrice', col='MSSubClass', data=df, kind='bar', col_wrap=5, aspect=0.6)
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
numerical_features = df.select_dtypes(include=[np.number])
numerical_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.009601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.357056 -0.139781     0.032628
# LotFrontage   -0.009601   -0.357056     1.000000  0.306795     0.234196
# LotArea       -0.033226   -0.139781     0.306795  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.234196  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.052820 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.117598  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.082746  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.179700  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.215828  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.043340  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.122156 -0.002618     0.308159
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    22.024023    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    60.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    70.049958    9478.500000     6.000000
# 75%    1095.250000    70.000000    79.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df['SaleCondition'].value_counts()
# Out:
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: SaleCondition, dtype: int64

# %%
df['Condition1'].value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
df['Condition2'].value_counts()
# Out:
# Norm      1445
# Feedr        6
# RRNn         2
# PosN         2
# Artery       2
# RRAe         1
# PosA         1
# RRAn         1
# Name: Condition2, dtype: int64

# %%
df['SaleType'].value_counts()
# Out:
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLw       5
# ConLI       5
# CWD         4
# Oth         3
# Con         2
# Name: SaleType, dtype: int64

# %%
df['Neighborhood'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df.corr(),linewidths=.55,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %%
cols = dfcorr.nlargest(10, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values,
                 xticklabels=cols.values)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1338, 76)

# %%
sns.distplot(df.SalePrice)

# %%
df['LogOfPrice'] = np.log(df.SalePrice)
df.drop(["SalePrice"], axis=1, inplace=True)

# %%
df.skew().sort_values()
# Out:
# YearBuilt        -0.677966
# GarageYrBlt      -0.669457
# YearRemodAdd     -0.563345
# BedroomAbvGr     -0.058165
# FullBath         -0.014175
# Id                0.000844
# YrSold            0.109344
# GarageCars        0.200432
# MoSold            0.205257
# LogOfPrice        0.290110
# OverallQual       0.315218
# BsmtFullBath      0.459865
# HalfBath          0.554013
# Fireplaces        0.570838
# TotRmsAbvGrd      0.673364
# 2ndFlrSF          0.769147
# GarageArea        0.807078
# OverallCond       0.897541
# BsmtUnfSF         0.935363
# MSSubClass        1.391901
# 1stFlrSF          1.397431
# GrLivArea         1.430307
# WoodDeckSF        1.481740
# BsmtFinSF1        1.693397
# TotalBsmtSF       2.214029
# OpenPorchSF       2.250952
# LotFrontage       2.479517
# MasVnrArea        2.582685
# EnclosedPorch     3.205286
# BsmtHalfBath      3.847909
# ScreenPorch       3.916848
# BsmtFinSF2        4.146519
# KitchenAbvGr      5.943561
# 3SsnPorch        10.096553
# ...

# %%
y = df.LogOfPrice

# %%
df = df.select_dtypes(include=["int64","float64"]) 
X = df.drop(["LogOfPrice"],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                    X, y, random_state=3, test_size=.25)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf.score(X_test,y_test)
# Out:
# 0.875426999783944

# %%
df = DecisionTreeRegressor()

# %%
df.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
df.score(X_test,y_test)
# Out:
# 0.7786112337254825

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(X_test,y_test)
# Out:
# 0.8839572248243495

# %%
gd=GradientBoostingRegressor()

# %%
gd.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gd.score(X_test,y_test)
# Out:
# 0.9018516468464821

# %%
ad=AdaBoostRegressor()

# %%
ad.fit(X_train,y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)

# %%
ad.score(X_test,y_test)
# Out:
# 0.8343803827465062

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
ET=ExtraTreesRegressor()

# %%
ET.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
ET.score(X_test,y_test)
# Out:
# 0.8750787090145361

# %%
print ("R^2 is: \n", gd.score(X_test, y_test))
# Out:
# R^2 is:
#  0.9018516468464821

# %%
predictions = gd.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \n', mean_squared_error(y_test, predictions))
# Out:
# RMSE is:
#  0.015399974467521118

# %%
from sklearn.model_selection import cross_val_score

# %%
gd_cv = cross_val_score(gd, X, y, cv = 10, scoring= 'r2')
print("Cross-validation results: ", gd_cv)
print("R2: ", gd_cv.mean())
# Out:
# Cross-validation results:  [0.85395803 0.89946006 0.92141352 0.82537071 0.86571366 0.89582919
#  0.90386485 0.91196391 0.88319311 0.85825878]
# R2:  0.8819025822877744

# %%
from sklearn.linear_model import Ridge, Lasso

# %%
model= Ridge(alpha = 10)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
#       random_state=None, solver='auto', tol=0.001)

# %%
model_cv = cross_val_score(model, X, y, cv = 10, scoring = 'r2')

# %%
print ("Cross-validation results: ", model_cv)
# Out:
# Cross-validation results:  [0.86434685 0.88633027 0.90001313 0.77473232 0.86275409 0.87238722
#  0.88818637 0.89026646 0.34344152 0.85497964]

# %%
print ("R2: ", model_cv.mean())
# Out:
# R2:  0.8137437874787887

# %%
lasso = Lasso(alpha = .0001)

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_cv = cross_val_score(lasso, X, y, cv = 10, scoring = 'r2')
print ("Cross-validation results: ", lasso_cv)
print ("R2: ", lasso_cv.mean())
# Out:
# Cross-validation results:  [0.86391628 0.88605974 0.90008388 0.77426867 0.86268146 0.87283031
#  0.88783653 0.88943714 0.34436167 0.85441977]
# R2:  0.8135895456114369
# C:\Users\sodainmind\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1441369217008521, tolerance: 0.017120195635428877
#   positive)
# C:\Users\sodainmind\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.095954575396835, tolerance: 0.017377566115747485
#   positive)
# C:\Users\sodainmind\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.1229822736440198, tolerance: 0.01713561056323743
# ...

# %%
from sklearn.externals import joblib
# Out:
# C:\Users\sodainmind\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
joblib.dump(gd,'data.csv')
# Out:
# ['data.csv']

# %%
model=joblib.load('data.csv')

# %%
model
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
rf_from_joblib = joblib.load('filename.pkl')

# %%
rf_from_joblib
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
